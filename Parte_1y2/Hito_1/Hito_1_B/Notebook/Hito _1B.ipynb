# %% [markdown]
# ## Segunda Parte Hito 1:
#
# Para finalizar esta primera parte realizaremos lo solicitado en la consigna del trabajo:
#
# * **Selección y Preparación del Modelo**
#
# • Elegir los modelos de machine learning o deep learning que se entrenarán. Justificar
# la elección en base al tipo de problema (clasificación, regresión, etc.), las características del
# dataset y el rendimiento esperado de cada algoritmo.
#
# • Evaluación: La justificación de los modelos seleccionados se evaluará con 1 puntos.
#
# • Preprocesamiento de Datos: Realizar el preprocesamiento adecuado para cada modelo,
#   asegurando que los datos están en un formato compatible y optimizado para los algoritmos seleccionados
#   (normalización, estandarización, codificación, etc.).

# %% [markdown]
# ## Justificación Académica de los Modelos Seleccionados
#
# ### Introducción
#
# La elección de los modelos en un proyecto de Ciencia de Datos es una decisión de extrema importancia que debe ser rigurosamente justificada, especialmente en el contexto de un trabajo de fin de máster. Esta justificación no solo valida la metodología empleada, sino que también demuestra una comprensión profunda de las capacidades y limitaciones de los algoritmos de Machine Learning en relación con el problema de investigación. En este documento, se presenta la justificación académica para la selección de los siguientes modelos de clasificación: Regresión Logística, Random Forest Classifier, Gradient Boosting y Perceptrón Multicapa (MLP) / Red Neuronal. Cada uno de estos modelos ha sido elegido estratégicamente para ofrecer una visión metodológica integral, permitiendo una evaluación exhaustiva del problema y la optimización de los resultados.
#
# La metodología de selección se basa en la búsqueda de un equilibrio entre la interpretabilidad, la robustez, el rendimiento predictivo y la capacidad de explorar diferentes paradigmas de aprendizaje automático. Desde un modelo lineal de referencia hasta técnicas de ensamble avanzadas y una incursión en el aprendizaje profundo, la combinación de estos algoritmos permite no solo identificar el modelo más adecuado para la tarea, sino también comprender las características intrínsecas de los datos y la complejidad de las relaciones subyacentes. Esta aproximación sistemática asegura que las conclusiones derivadas del análisis sean sólidas, fiables y académicamente defendibles.
#
#
#
# ### Justificación Académica de los Modelos Seleccionados
#
# Para la selección de modelos en este proyecto, se ha optado por un conjunto de algoritmos de clasificación que, en su conjunto, ofrecen una visión metodológica integral del problema. Cada modelo aporta una contribución específica y es fundamental para la fase de comparación y optimización.
#
# #### 1. Regresión Logística (Logistic Regression) 📊
#
# **Contribución Metodológica:** La Regresión Logística se incluye como el modelo de línea base (baseline) lineal fundamental. Su función principal es establecer un umbral de rendimiento inicial, permitiendo determinar si la complejidad de los modelos no lineales es necesaria para mejorar la precisión. Es vital para la interpretabilidad de los coeficientes de las *features*, lo que facilita la comprensión de la influencia de cada variable en la predicción. Académicamente, su inclusión es crucial para demostrar la mejora incremental que ofrecen modelos más complejos y para validar la necesidad de técnicas avanzadas cuando las relaciones lineales no son suficientes para capturar la complejidad de los datos [1].
#
# #### 2. Random Forest Classifier (Bosque Aleatorio) 🌳
#
# **Contribución Metodológica:** El Random Forest representa una técnica de ensamble por *bagging* (Bootstrap Aggregating). Se elige por su robustez, su baja sensibilidad al sobreajuste (*overfitting*) y su capacidad inherente para manejar la no linealidad en los datos. Su principal aporte es que permite la identificación de la importancia de las *features*, mejorando la interpretabilidad del conjunto de predictores. La combinación de múltiples árboles de decisión reduce la varianza y mejora la estabilidad del modelo, lo que lo convierte en una opción sólida para problemas de clasificación complejos y una excelente alternativa a los modelos lineales cuando la interpretabilidad a nivel de característica es importante [2].
#
# #### 3. Gradient Boosting (Gradient Boosting Classifier) 🚀
#
# **Contribución Metodológica:** El Gradient Boosting se incluye como una técnica de ensamble secuencial (*boosting*). Su propósito es alcanzar el máximo rendimiento predictivo corrigiendo iterativamente los errores de los árboles anteriores. Es un modelo clave en la fase de optimización (Hito 3) para determinar el límite superior de precisión alcanzable en el problema. Su capacidad para aprender de los errores residuales de modelos previos lo hace excepcionalmente potente para problemas donde se requiere una alta precisión, a menudo superando a otros algoritmos en competiciones de Machine Learning. Su inclusión permite explorar el potencial de mejora continua a través de la combinación de modelos débiles [3].
#
# #### 4. Perceptrón Multicapa (MLP) / Red Neuronal 🧠
#
# **Contribución Metodológica:** Su inclusión permite evaluar el rendimiento de un modelo de Deep Learning de entrada. El MLP es esencial para contrastar la efectividad del aprendizaje jerárquico de *features* (propio de las redes neuronales) frente a los métodos de ensamble clásicos, lo cual es fundamental en la fase de Comparación (Hito 4). A diferencia de la Regresión Logística (RL), las Redes Neuronales (RN) son capaces de aprender patrones y relaciones muy complejas y no lineales en los datos, lo que se revela gran importancia para la predicción de la variable objetivo, ya que las relaciones entre las variables X e Y podrían ser muy sutiles. El aprendizaje de representaciones en las capas ocultas de una RN es capaz de aprender representaciones de características más abstractas y útiles a partir de los datos de entrada, lo que a veces elimina la necesidad de una ingeniería exhaustiva de *features*. Además, en muchos problemas de clasificación, las RN, especialmente cuando se ajustan correctamente y se dispone de suficientes datos, alcanzan un rendimiento superior al de los modelos tradicionales de Machine Learning, justificado así su exploración como un candidato de alto rendimiento [4].
#
#
# ### Conclusión
#
# La selección de modelos en este trabajo de fin de máster en Ciencia de Datos ha sido un proceso deliberado y estratégicamente diseñado para abordar el problema de clasificación desde múltiples perspectivas. La inclusión de la Regresión Logística como *baseline* lineal, el Random Forest y Gradient Boosting como técnicas de ensamble robustas y de alto rendimiento, y el Perceptrón Multicapa como representante del aprendizaje profundo, permite una evaluación integral y comparativa. Esta aproximación no solo busca la optimización del rendimiento predictivo, sino que también facilita la interpretabilidad de los resultados y la comprensión de la complejidad subyacente de los datos.
#
# Cada modelo aporta un valor único al análisis: la Regresión Logística establece un punto de referencia interpretable; el Random Forest ofrece robustez y capacidad para identificar la importancia de las características; el Gradient Boosting empuja los límites del rendimiento predictivo a través de la corrección iterativa de errores; y el Perceptrón Multicapa explora el potencial del aprendizaje jerárquico de representaciones y la capacidad de modelar relaciones altamente no lineales. La combinación de estos modelos asegura que el proyecto no solo alcance sus objetivos de rendimiento, sino que también proporcione una justificación académica sólida y una comprensión profunda de las decisiones metodológicas tomadas.
#
# Esta justificación académica subraya el rigor científico del trabajo, demostrando que la elección de los modelos no es arbitraria, sino el resultado de un análisis cuidadoso de sus propiedades, ventajas y limitaciones en el contexto específico del problema. Al presentar un abanico de modelos que van desde lo lineal y simple hasta lo no lineal y complejo, el estudio se posiciona para ofrecer conclusiones robustas y bien fundamentadas, contribuyendo significativamente al campo de la Ciencia de Datos.
#
# #### Referencias
#
# [1] Codificando Bits. "¿Cómo seleccionar el mejor modelo en un problema de Machine Learning?". Disponible en: https://codificandobits.com/blog/seleccion-modelo-machine-learning/
# [2] Datasource.ai. "Métricas De Evaluación De Modelos En El Aprendizaje Automático". Disponible en: https://www.datasource.ai/es/data-science-articles/metricas-de-evaluacion-de-modelos-en-el-aprendizaje-automatico
# [3] ResearchGate. "Evaluación de Modelos de Machine Learning para la Predicción de...". Disponible en: https://www.researchgate.net/publication/385719743_Prediccion_del_rendimiento_academico_utilizando_modos_de_aprendizaje_automatico_Una_revision_sistematica_de_la_literatura
# [4] Sedici.unlp.edu.ar. "Modelo basado en la toma decisiones con criterios múltiples para la elección de metodologías de data science". Disponible en: https://sedici.unlp.edu.ar/handle/10915/67097

# %% [markdown]
# ### 1. Librerias

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ### 2. Inspección

# %%
data = pd.read_csv('votaciones_europeas.csv')

data.head()
# Out:
#    Renta_Per_Capita_2023_miles_euros  edad  ingreso_hogar  \
# 0                              23218    44              4
# 1                              23218    37              1
# 2                              23218    60              6
# 3                              23218    42              5
# 4                              23218    35              6
#
#    probabilidad_voto_generales  habitantes_municipio_codificado  \
# 0                          1.0                                3
# 1                          0.8                                3
# 2                          1.0                                5
# 3                          1.0                                5
# 4                          1.0                                5
#
#    Renta_Per_Capita_2023_miles_euros_escalada  categorico_pca_0  \
# 0                                   -1.064366         -0.539439
# 1                                   -1.064366         -0.539439
# ...

# %%
data.shape
# Out:
# (2479, 23)

# %% [markdown]
# ###  3. Preprocesamiento de Datos (Data Preprocessing).

# %% [markdown]
# #### 3.1 Explicación Metodológica del Código de Preparación
#
# El código escrito realiza los pasos fundamentales de Separación de Datos y Estandarización de Features,
# procesos necesarios que deben ejecutarse rigurosamente antes de iniciar el entrenamiento de modelos de Machine Learning (ML).
#
# 1. Separación de Variables (X e Y) y División de Datos
#
# Esta etapa define el problema de clasificación y asegura la reproducibilidad del estudio:
#
# Definición de Variables: Se aísla la Variable Objetivo (Y = data['bloque_ideologico_encoded']), que el modelo intentará predecir,
# del conjunto de Variables Predictoras o Features (X), que son los insumos del modelo.
#
# División (Train-Test Split): Se emplea train_test_split para particionar el dataset en conjuntos de Entrenamiento (80%) y Prueba (20%).
#
# Finalidad Académica: Reservar un conjunto de prueba (X_test, Y_test) permite una evaluación final imparcial del rendimiento del modelo,
# garantizando que este sea validado sobre datos que nunca ha visto, previniendo así el sobreajuste (overfitting).
#
# El uso de random_state=42 garantiza que esta partición sea reproducible en futuras ejecuciones.
#
# 2. Escalamiento de Features (StandardScaler)
#
# El escalado es obligatorio para los modelos basados en la distancia o el gradiente.
#
# Identificación de Variables a Escalar: Las variables edad, ingreso_hogar, probabilidad_voto_generales, Renta_Per_Capita_2023_miles_euros
# y Renta_Per_Capita_2023_miles_euros_escalada son identificadas como variables numéricas con magnitudes o rangos dispares.
#
# Aplicación del StandardScaler:
#
# Normalización: Este método transforma los datos de modo que la distribución de cada feature tenga una media (μ)
# de cero y una desviación estándar (σ) de uno.
#
# Necesidad Algorítmica: Modelos como la Regresión Logística, SVM y MLP son sensibles a la escala. Sin la estandarización,
# las features con rangos amplios (ej., la renta) dominarían el cálculo de la función de pérdida y la optimización del gradiente,
# sesgando el aprendizaje.
#
# Prevención de Data Leakage: Se utiliza fit_transform solo en el conjunto de entrenamiento (X_train) para que el escalador aprenda
# los parámetros (μ y σ) exclusivamente de esos datos. Luego, se utiliza solo transform en el conjunto de prueba (X_test) para aplicar
# la misma transformación, evitando así la fuga de información (información del test set al train set).

# %%
# 1. Definir la Variable Objetivo (Y) y las Features (X)
Y = data['bloque_ideologico_encoded']
X = data.drop(columns=['bloque_ideologico_encoded']) 

# 2. Separar datos de entrenamiento y prueba
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# 3. Identificar columnas numéricas para escalar
# Del CSV, estas son las que se tienen que escalar:
columnas_a_escalar = [
    'edad', 
    'ingreso_hogar',
    'probabilidad_voto_generales',
    'Renta_Per_Capita_2023_miles_euros', 
    'Renta_Per_Capita_2023_miles_euros_escalada' # Aunque ya está escalada, el StandardScaler es buena práctica.
]

# 4. Aplicar el StandardScaler SOLO a las columnas de entrenamiento
scaler = StandardScaler()
X_train[columnas_a_escalar] = scaler.fit_transform(X_train[columnas_a_escalar])

# 5. Aplicar la misma transformación a los datos de prueba
X_test[columnas_a_escalar] = scaler.transform(X_test[columnas_a_escalar])

# %% [markdown]
# ### 3.1.1 Se guardan los valores del Train y el Test para ser reutilizados
#
# y no tener que volver a repetir la línea de código anterior obteniendo así mas efciciencia.

# %%
import joblib

# Los DataFrames X_train, X_test, Y_train y Y_test ya están en la memoria,
# listos y escalados. Ahora los guardamos para el Notebook 3 (Hito 2).

joblib.dump(X_train, 'X_train.pkl')
joblib.dump(X_test, 'X_test.pkl')
joblib.dump(Y_train, 'Y_train.pkl')
joblib.dump(Y_test, 'Y_test.pkl')

print("Datos de entrenamiento y prueba guardados con éxito en formato .pkl!")
# Out:
# Datos de entrenamiento y prueba guardados con éxito en formato .pkl!

# %% [markdown]
# #### 3.2. Inspección Visual del Escalado (Gráficos) 📈
# El objetivo es confirmar que las columnas numéricas ahora tienen una distribución estándar.
#
# A. Histogramas de la Distribución
#
# Compara las distribuciones de las columnas antes y después del escalado para confirmar que están centradas alrededor de cero.
#
# B. Gráficos de Caja (Box Plots)

# %%
plt.figure(figsize=(12, 5))

# Histograma para la Renta (ANTES del escalado)
plt.subplot(1, 2, 1)
sns.histplot(data['Renta_Per_Capita_2023_miles_euros'], kde=True)
plt.title('Renta ANTES del Escalado (Original)')

# Histograma para la Renta (DESPUÉS del escalado)
# Usamos el X_train escalado
plt.subplot(1, 2, 2)
sns.histplot(X_train['Renta_Per_Capita_2023_miles_euros'], kde=True, color='purple')
plt.title('Renta DESPUÉS del Escalado (Centrada)')

plt.tight_layout()
plt.show()
# Out:
# /Users/daniel/miniconda3/envs/TFM/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/daniel/miniconda3/envs/TFM/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### 3.2.A Análisis de la Estandarización de la Renta (Histogramas) 📊
# El propósito de esta visualización es confirmar el éxito del StandardScaler al preparar la feature Renta_Per_Capita_2023_miles_euros para
# los modelos sensibles a la escala (Regresión Logística, SVM, MLP).
#
# El gráfico compara la distribución de la renta antes y después de ser procesada en el conjunto de entrenamiento (X_train).
#
# Histograma Izquierdo: ANTES del Escalado (Original)
#
# Observación	Implicacia Metodológica
# Sesgo Asimétrico: La distribución muestra una asimetría (sesgo) positiva y una cola larga hacia la derecha.
# Magnitud Desigual: El rango de valores es amplio (desde cero hasta valores altos).
# Conclusión: Si se usara esta feature sin modificar, su gran magnitud y varianza dominarían la función de costo de los modelos basados
# en el gradiente, resultando en un entrenamiento subóptimo.
#
#
# Histograma Derecho: DESPUÉS del Escalado (Centrada)
#
# Observación	Confirmación del StandardScaler
# Re-Centrado en Cero	El pico central (moda/media) de la distribución se ha desplazado y se sitúa exactamente en el punto X=0.
# Mantenimiento de la Forma: La distribución mantiene su asimetría (la cola sigue a la derecha).
# Rango Comprimido: El eje X muestra ahora valores que se agrupan en torno a cero (típicamente entre -2 y +4).

# %%
plt.figure(figsize=(8, 6))

# Selecciona las columnas escaladas
columnas_escaladas = ['edad', 'ingreso_hogar', 'Renta_Per_Capita_2023_miles_euros']

# Crea un box plot para todas las columnas escaladas
sns.boxplot(data=X_train[columnas_escaladas])
plt.title('Distribución de Features Numéricas Escalaas')
plt.ylabel('Valor Estandarizado')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# #### 3.2.B Análisis de la Distribución de Features Escaladas (Box Plot) 📦
# El objetivo de este Box Plot es verificar visualmente el éxito de la estandarización, que busca transformar las variables
# para que tengan una media (μ) cercana a cero y una desviación estándar (σ) cercana a uno.
#
# 1. Confirmación de Centralización (Media ≈0)
#
# Observación en el Gráfico:
# Conclusión Metodológica
# La línea central de cada caja (la mediana) se alinea perfectamente con el valor 0 en el eje Y.
# Éxito en el Centrado se confirma que el StandardScaler ha restado correctamente la media a todos los valores, eliminando
# la diferencia en la magnitud de origen (miles en la Renta vs. decenas en la Edad).
#
# Confirmación de la Escala (Desviación Estándar ≈1)
#
# Observación en el Gráfico:
# Conclusión Metodológica
# La longitud de las cajas (Rango Intercuartílico) y la extensión de los bigotes son visualmente comparables entre las tres features.

# %% [markdown]
# ### 3.2.C Distribución y Outliers
#
# Edad: La distribución está bastante simétrica y concentrada. Muestra outliers en ambos extremos, pero en menor medida que otras variables.
#
# Ingreso Hogar y Renta Per Cápita: Ambas distribuciones muestran una mayor cantidad de outliers positivos (por encima del bigote superior).
# Esto es consistente con la naturaleza de los datos de ingresos o renta, que suelen tener colas largas debido a los valores extremadamente altos.
#
# Nota Metodológica: Los outliers no se eliminan con el escalado, simplemente se posicionan en términos de desviaciones estándar.
# Estos puntos confirman la asimetría positiva de la distribución de ingresos que ya observaste en los histogramas anteriores.
#
# Conclusión General: El proceso de escalado ha sido validado. El conjunto de features numéricas está listo y estandarizado para el entrenamiento de los modelos de clasificación.

# %% [markdown]
# ### 4. Creación del dataset para funcione como punto de resguardo.

# %%
# Paso 1: Asignar el DataFrame existente a la nueva variable 'data_ML'
data_ML = data

# Paso 2: Usar .to_csv() en la nueva variable para guardar el archivo

data_ML.to_csv('data_ML.csv', index=False)
